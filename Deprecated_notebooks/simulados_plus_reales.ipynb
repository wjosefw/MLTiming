# %% [markdown]
# # **IMPORTADO DE MÓDULOS/FUNCIONES**

# %%
import numpy as np
import matplotlib.pyplot as plt

from scipy.interpolate import interp1d
from scipy.ndimage import gaussian_filter1d

import tensorflow as tf
tf.version.VERSION

from tensorflow.keras.layers import Input
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense
from tensorflow.keras import initializers
from keras.regularizers import l2
# Out:
# 2024-07-22 15:45:29.021155: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-07-22 15:45:29.046391: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-07-22 15:45:29.431326: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
V55= np.load('/home/josea/Co60_5cm_5cm.npy')
V28= np.load('/home/josea/Co60_2cm_8cm.npy')
V82= np.load('/home/josea/Co60_8cm_2cm.npy')

# %%
source = 'Co60'
path = '/home/josea/PracticaTimingDigital/pulso_' + source + '_filt_norm.npz'

data = np.load(path)
pulsos_practica_master = data['data']

# %%
import sys
sys.path.append('/home/josea/DEEP_TIMING/DEEP_TIMING_VS')

# %%
from functions import gauss, gauss_fit, momentos, pulso, get_mean_pulse_from_set, delay_pulse_pair, create_and_delay_pulse_pair, move_to_reference, pulso_escalon, pulso_sigmoid, create_position
from Models import model_definition

# %% [markdown]
# # **INTERPOLATION**

# %%
#--------------------------------Interpolar pulsos reales---------------------------------
input = V28
EXTRASAMPLING = 8
Nt = np.shape(input)[1]
Nt_new = Nt *  EXTRASAMPLING
time_step = 0.2
new_time_step = time_step / EXTRASAMPLING

tiempo = np.linspace(0, Nt, Nt)
tiempo_new = np.linspace(0,Nt,Nt_new)

interp_func_V28 = interp1d(tiempo,V28, kind = 'cubic', axis = 1)
new_V28 = interp_func_V28(tiempo_new)

interp_func_V55 = interp1d(tiempo,V55, kind = 'cubic', axis = 1)
new_V55 = interp_func_V55(tiempo_new)

interp_func_V82 = interp1d(tiempo,V82, kind = 'cubic', axis = 1)
new_V82 = interp_func_V82(tiempo_new)

interp_func_practica = interp1d(tiempo,pulsos_practica_master, kind = 'cubic', axis = 1)
new_pulsos_practica = interp_func_practica(tiempo_new)

#---------------------------------------------------------------- Align the pulses -----------------------------------
align_steps = 20
new_pulsos_practica[:,:,1] = np.roll(new_pulsos_practica[:,:,1], align_steps)
new_pulsos_practica[:,:align_steps,1] = np.random.normal(scale = 1e-3, size = align_steps)

#----------------------------------------------------- Print important information -----------------------------------
print('Number of time points: %.d' % (Nt))
print('Time step: %.2f' % (time_step))
print('New number of time points: %.d' % (Nt_new))
print('New time step: %.4f' % (new_time_step))
# Out:
# Number of time points: 600
# Time step: 0.20
# New number of time points: 4800
# New time step: 0.0250

# %% [markdown]
# # **GENERATE MEAN PULSE PER DETECTOR**

# %%
mean_pulse_dec0 = get_mean_pulse_from_set(new_pulsos_practica, channel = 0)
mean_pulse_dec1 = get_mean_pulse_from_set(new_pulsos_practica, channel = 1)

#-------------------------------------- Plot cropped mean pulses -----------------------------
start = 50*EXTRASAMPLING
stop = 75*EXTRASAMPLING

plt.plot(mean_pulse_dec0[start:stop], 'b-', label = 'Mean pulse detector 0')
plt.plot(mean_pulse_dec1[start:stop], 'r-', label = 'Mean pulse detector 1')
plt.legend()

# %% [markdown]
# # **PREPROCESSING**

# %%
Num_casos = 4000
Nc = 2

t_shift = 8 #In time steps
t = np.linspace(0, Nt, Nt_new)
#t0 = 550 + np.random.randint(100, size = Num_casos)
t0 = 65 + np.random.randint(10, size = Num_casos)

# %%
#------------------------------------- Define size of train set from datos practica ---------------------------------
Ntrain_practica = int(1*new_pulsos_practica.shape[0])
Ntest_practica = int(0.0*new_pulsos_practica.shape[0])
print('Número de casos de entrenamiento de la práctica: ', Ntrain_practica)
print('Número de casos de Test de la práctica: ', Ntest_practica)
# Out:
# Número de casos de entrenamiento de la práctica:  2211
# Número de casos de Test de la práctica:  0

# %%
#--------------------------------- Detector 0 definitions -------------------------
tau_rise_dec0 = 20
tau_drop_dec0 = 150
Photon_yield = 100
center_window_dec0 = 0.3
rise_window_dec0 = 0.3

#--------------------------------- Detector 1 definitions -------------------------
tau_rise_dec1 = 15
tau_drop_dec1 = 150
Photon_yield = 100
center_window_dec1 = 0.3
rise_window_dec1 = 0.3

# %%
#pulso_original_dec0 = pulso_escalon(t, 550, A = 0.6)
#pulso_original_dec1 = pulso_escalon(t, 550, A = 0.6)
#pulso_original_dec0 =  pulso_sigmoid(tiempo_new, 80, A = Photon_yield, center_window = center_window_dec0, rise_window = rise_window_dec0, tau_rise = tau_rise_dec0, tau_drop = tau_drop_dec0, NOISE = False)
#pulso_original_dec1 =  pulso_sigmoid(tiempo_new, 80, A = Photon_yield, center_window = center_window_dec1, rise_window = rise_window_dec1, tau_rise = tau_rise_dec1, tau_drop = tau_drop_dec1, NOISE = False)
pulso_original_dec0 = pulso(t, 70, tau_rise = tau_rise_dec0, tau_drop = tau_drop_dec0)
pulso_original_dec1 = pulso(t, 70, tau_rise = tau_rise_dec1, tau_drop = tau_drop_dec1)



plt.figure(figsize = (12,4))
plt.subplot(121)
plt.plot(pulso_original_dec0[start:stop],'r-', label = 'Simulated pulse')
plt.plot(mean_pulse_dec0[start:stop],'b-', label = 'Mean pulse')
plt.legend()
plt.xlabel('Time points')
plt.ylabel('Voltage [A.U]')
plt.title('Detector 0')

plt.subplot(122)
plt.plot(pulso_original_dec1[start:stop],'r-', label = 'Simulated pulse')
plt.plot(mean_pulse_dec1[start:stop],'b-', label = 'Mean pulse')
plt.legend()
plt.xlabel('Time points')
plt.ylabel('Voltage [A.U]')
plt.title('Detector 1')
# Out:
# Text(0.5, 1.0, 'Detector 1')

# %%
#------------------------------ Create simulated pulses ---------------------------------
INPUT_dec0 = np.zeros((Num_casos, Nt_new))
INPUT_dec1 = np.zeros((Num_casos, Nt_new))

for i in range(Num_casos):
  #PULSO_dec0 = pulso_escalon(t, t0[i], A = 0.6)
  #PULSO_dec1 = pulso_escalon(t, t0[i], A = 0.6)
  PULSO_dec0 = pulso(t, t0[i], tau_rise = tau_rise_dec0, tau_drop = tau_drop_dec0)
  PULSO_dec1 = pulso(t, t0[i], tau_rise = tau_rise_dec1, tau_drop = tau_drop_dec1)
  INPUT_dec0[i,:] = PULSO_dec0
  INPUT_dec1[i,:] = PULSO_dec1

# %%
#-------------------------------- Delay simulated pulses --------------------------------------------

#delays_dec0, moved_pulses_dec0 = move_to_reference(mean_pulse_dec0, np.expand_dims(INPUT_dec0, axis = -1), start = start, stop = stop, max_delay = 240, channel = 0)
#delays_dec1, moved_pulses_dec1 = move_to_reference(mean_pulse_dec1, np.expand_dims(INPUT_dec1, axis = -1), start = start, stop = stop, max_delay = 240, channel = 0)
#INPUT_dec0, REF_dec0 = create_and_delay_pulse_pair(moved_pulses_dec0, new_time_step, delay_steps = 32, NOISE = True)
#INPUT_dec1, REF_dec1 = create_and_delay_pulse_pair(moved_pulses_dec1, new_time_step, delay_steps = 32, NOISE = True)
INPUT_dec0, REF_dec0 = create_and_delay_pulse_pair(INPUT_dec0[:,start:stop], new_time_step, delay_steps = 32, NOISE = True)
INPUT_dec1, REF_dec1 = create_and_delay_pulse_pair(INPUT_dec1[:,start:stop], new_time_step, delay_steps = 32, NOISE = True)



#--------------------------------- Move rest of the pulses to align with mean and then delay them ---------------------------------------

#delays2_dec0, moved_pulses2_dec0 = move_to_reference(mean_pulse_dec0, new_pulsos_practica[:Ntrain_practica,:,:], start = start, stop = stop, max_delay = 240, channel = 0)
#delays2_dec1, moved_pulses2_dec1 = move_to_reference(mean_pulse_dec1, new_pulsos_practica[:Ntrain_practica,:,:], start = start, stop = stop, max_delay = 240, channel = 1)
#INPUT2_dec0, REF2_dec0 = create_and_delay_pulse_pair(moved_pulses2_dec0, new_time_step, delay_steps = 32, NOISE = True)
#INPUT2_dec1, REF2_dec1 = create_and_delay_pulse_pair(moved_pulses2_dec1, new_time_step, delay_steps = 32, NOISE = True)
INPUT2_dec0, REF2_dec0 = create_and_delay_pulse_pair(new_pulsos_practica[:Ntrain_practica,start:stop,0], new_time_step, delay_steps = 32, NOISE = True)
INPUT2_dec1, REF2_dec1 = create_and_delay_pulse_pair(new_pulsos_practica[:Ntrain_practica,start:stop,1], new_time_step, delay_steps = 32, NOISE = True)


#--------------------------------- Create train set ----------------------------------------------------
trainX_dec0 = np.concatenate((INPUT_dec0, INPUT2_dec0), axis = 0)
trainX_dec1 = np.concatenate((INPUT_dec1, INPUT2_dec1), axis = 0)

REF_train_dec0 = np.concatenate((REF_dec0, REF2_dec0))
REF_train_dec1 = np.concatenate((REF_dec1, REF2_dec1))

# %%
plt.figure(figsize = (12,4))

plt.subplot(121)
for i in range(trainX_dec0.shape[0]):
    plt.plot(trainX_dec0[i,:,0],'b-')
plt.plot(mean_pulse_dec0[start:stop],'r-')
plt.title('Detector 0')

plt.subplot(122)
for i in range(trainX_dec1.shape[0]):
    plt.plot(trainX_dec1[i,:,0],'b-')
plt.plot(mean_pulse_dec1[start:stop],'r-')
plt.title('Detector 1')
# Out:
# Text(0.5, 1.0, 'Detector 1')

# %%
#--------------------------------------- Calculate moments ---------------------------------------------------
M_Train_dec0 = momentos(trainX_dec0)
M_Train_dec1 = momentos(trainX_dec1)

#------------------------------------------ Normalize -------------------------------------------------
min_dec0 = np.min(M_Train_dec0)
max_dec0 = np.max(M_Train_dec0)

min_dec1 = np.min(M_Train_dec1)
max_dec1 = np.max(M_Train_dec1)

M_Train_dec0 = (M_Train_dec0 - min_dec0)/(max_dec0 - min_dec0)
M_Train_dec1 = (M_Train_dec1 - min_dec1)/(max_dec1 - min_dec1)

#------------------------------------ Print Important information -----------------------------------------------
NM = np.shape(M_Train_dec0)[1]
print(M_Train_dec0.shape, "NM =", NM)
print('Min detector 0: ', min_dec0)
print('Max detector 0: ', max_dec0)

NM = np.shape(M_Train_dec1)[1]
print(M_Train_dec1.shape, "NM =", NM)
print('Min detector 1: ', min_dec1)
print('Max detector 1: ', max_dec1)
# Out:
# (6211, 4, 2) NM = 4
# Min detector 0:  -0.6051627907881251
# Max detector 0:  24.713051766462478
# (6211, 4, 2) NM = 4
# Min detector 1:  -0.4755589459237599
# Max detector 1:  29.10824956220527

# %%
plt.hist(M_Train_dec0[:Num_casos,0,0], alpha = 0.5, label = 'Simulados');
plt.hist(M_Train_dec0[Num_casos:,0,0], alpha = 0.5, label = 'Reales');
plt.legend()

# %% [markdown]
# # **FULL TOF**

# %%
#-------------------------------------- Create Reference pulses set ----------------------------------------
REFERENCE_PULSE_dec0 = np.tile(new_V82[0,start:stop,:], (trainX_dec0.shape[0],2,1)).swapaxes(1,2)
REFERENCE_PULSE_dec1 = np.tile(new_V82[0,start:stop,:], (trainX_dec1.shape[0],2,1)).swapaxes(1,2)

M_REF_dec0 = momentos(REFERENCE_PULSE_dec0)
M_REF_dec1 = momentos(REFERENCE_PULSE_dec1)

M_REF_dec0 = (M_REF_dec0 - min_dec0)/(max_dec0 - min_dec0)
M_REF_dec1 = (M_REF_dec1 - min_dec1)/(max_dec1 - min_dec1)

# %%
#-------------------------------------------- Create test set -------------------------------------------------------------
#delays_test_dec0, moved_pulses_test_dec0 = move_to_reference(mean_pulse_dec0, new_V55, start = start, stop = stop, max_delay = 240, channel = 0)
#delays_test_dec1, moved_pulses_test_dec1 = move_to_reference(mean_pulse_dec1, new_V55, start = start, stop = stop, max_delay = 240, channel = 1)


#------------------------------- Create other positions ------------------------------------------------------------------
#new_V55 = np.stack((moved_pulses_test_dec0, moved_pulses_test_dec1), axis = 2)
#new_V28 = create_position(new_V55, channel_to_move = 1, channel_to_fix = 0, t_shift = t_shift, NOISE = True)
#new_V82 = create_position(new_V55, channel_to_move = 0, channel_to_fix = 1, t_shift = t_shift, NOISE = True)

new_V55 = new_V55[:,start:stop,:]
new_V28 = new_V28[:,start:stop,:]
new_V82 = new_V82[:,start:stop,:]



M_V55 = momentos(new_V55)
M_V55[:,:,0] = (M_V55[:,:,0] - min_dec0)/(max_dec0 - min_dec0)
M_V55[:,:,1] = (M_V55[:,:,1] - min_dec1)/(max_dec1 - min_dec1)

M_V28 = momentos(new_V28)
M_V28[:,:,0] = (M_V28[:,:,0] - min_dec0)/(max_dec0 - min_dec0)
M_V28[:,:,1] = (M_V28[:,:,1] - min_dec1)/(max_dec1 - min_dec1)

M_V82 = momentos(new_V82)
M_V82[:,:,0] = (M_V82[:,:,0] - min_dec0)/(max_dec0 - min_dec0)
M_V82[:,:,1] = (M_V82[:,:,1] - min_dec1)/(max_dec1 - min_dec1)

# %%
epochs = 150
num_semillas = 5

epsilon = []
bias = []
std = []
training_loss_dec0 = []
training_loss_dec1 = []

TOFN_V28_list = []
TOFN_V55_list = []
TOFN_V82_list = []

directory = '/home/josea/temporal/'


for i in range(num_semillas):

  model_dec0 = model_definition(NM = NM, NN = 32, STD_INIT = 0.5)
  model_dec1 = model_definition(NM = NM, NN = 32, STD_INIT = 0.5)

  opt_dec0 = tf.keras.optimizers.AdamW(learning_rate = 1e-3)
  opt_dec1 = tf.keras.optimizers.AdamW(learning_rate = 1e-3)

  model_dec0.compile(optimizer = opt_dec0, loss = 'MSE')
  model_dec1.compile(optimizer = opt_dec1, loss = 'MSE')

  squared_sum = []
  MEC = []
  MSTD = []
  loss_dec0 = []
  loss_dec1 = []
  TOFN_V28_epoch = []
  TOFN_V55_epoch = []
  TOFN_V82_epoch = []

  for epoch in range(epochs):
     history_dec0 = model_dec0.fit(x = [M_Train_dec0[:,:,0], M_Train_dec0[:,:,1]], y = REF_train_dec0, epochs = 1, batch_size = 512, shuffle = True, verbose = 1)
     history_dec1 = model_dec1.fit(x = [M_Train_dec1[:,:,0], M_Train_dec1[:,:,1]], y = REF_train_dec1, epochs = 1, batch_size = 512, shuffle = True, verbose = 1)
     
     loss_dec0.append(history_dec0.history['loss'][-1])
     loss_dec1.append(history_dec1.history['loss'][-1])

    
     TOFN_dec0_REF_V82 = model_dec0.predict([M_V82[:,:,0],M_REF_dec0[:M_V82.shape[0],:,0]])
     TOFN_dec1_REF_V82 = model_dec1.predict([M_V82[:,:,1],M_REF_dec1[:M_V82.shape[0],:,0]])
     TOFN_dec0_REF_V55 = model_dec0.predict([M_V55[:,:,0],M_REF_dec0[:M_V55.shape[0],:,0]])
     TOFN_dec1_REF_V55 = model_dec1.predict([M_V55[:,:,1],M_REF_dec1[:M_V55.shape[0],:,0]])
     TOFN_dec0_REF_V28 = model_dec0.predict([M_V28[:,:,0],M_REF_dec0[:M_V28.shape[0],:,0]])
     TOFN_dec1_REF_V28 = model_dec1.predict([M_V28[:,:,1],M_REF_dec1[:M_V28.shape[0],:,0]])
    
     #TOFN_V28 = (np.squeeze(TOFN_dec0_REF_V28) - new_time_step*delays_test_dec0) - (np.squeeze(TOFN_dec1_REF_V28) - new_time_step*delays_test_dec1)
     #TOFN_V55 = (np.squeeze(TOFN_dec0_REF_V55) - new_time_step*delays_test_dec0) - (np.squeeze(TOFN_dec1_REF_V55) - new_time_step*delays_test_dec1)
     #TOFN_V82 = (np.squeeze(TOFN_dec0_REF_V82) - new_time_step*delays_test_dec0) - (np.squeeze(TOFN_dec1_REF_V82) - new_time_step*delays_test_dec1)

     TOFN_V28 = TOFN_dec0_REF_V28 - TOFN_dec1_REF_V28
     TOFN_V55 = TOFN_dec0_REF_V55 - TOFN_dec1_REF_V55
     TOFN_V82 = TOFN_dec0_REF_V82 - TOFN_dec1_REF_V82
    
     TOFN_V28_epoch.append(TOFN_V28)
     TOFN_V55_epoch.append(TOFN_V55)
     TOFN_V82_epoch.append(TOFN_V82)


     centroid_V28 = np.mean(TOFN_V28) - np.mean(TOFN_V55)
     centroid_V82 = np.mean(TOFN_V82) - np.mean(TOFN_V55)
     mean_error_centroid = (abs(centroid_V28 + 0.2) + abs(centroid_V82 - 0.2)) / 2
     mean_std = (np.std(TOFN_V82) + np.std(TOFN_V55) + np.std(TOFN_V28)) / 3
     
     squared_sum.append(np.sqrt(mean_error_centroid**2 + mean_std**2))
     MEC.append(mean_error_centroid)
     MSTD.append(mean_std)

     #model_dec0.save(directory + 'model_dec0_' + str(i) + '_' + str(epoch) + '.h5')
     #model_dec1.save(directory + 'model_dec1_' + str(i) + '_' + str(epoch) + '.h5')

  training_loss_dec0.append(loss_dec0)
  training_loss_dec1.append(loss_dec1)
  epsilon.append(squared_sum)
  bias.append(MEC)
  std.append(MSTD)

  TOFN_V28_list.append(TOFN_V28_epoch)
  TOFN_V55_list.append(TOFN_V55_epoch)
  TOFN_V82_list.append(TOFN_V82_epoch)

  tf.keras.backend.clear_session()

epsilon = np.array(epsilon, dtype = 'object')
bias = np.array(bias, dtype='object')
std = np.array(std, dtype='object')

training_loss_dec0 = np.array(training_loss_dec0, dtype = 'object')
training_loss_dec1 = np.array(training_loss_dec1, dtype = 'object')

TOFN_V28_array = np.array(TOFN_V28_list, dtype = 'object')
TOFN_V55_array = np.array(TOFN_V55_list, dtype = 'object')
TOFN_V82_array = np.array(TOFN_V82_list, dtype = 'object')
# Out:
# 2024-07-22 15:45:37.486184: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-07-22 15:45:37.486711: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-07-22 15:45:37.486769: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-07-22 15:45:37.487559: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-07-22 15:45:37.487621: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-07-22 15:45:37.487662: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-07-22 15:45:37.540004: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-07-22 15:45:37.540093: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-07-22 15:45:37.540148: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-07-22 15:45:37.540193: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1928] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 21639 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 4090, pci bus id: 0000:01:00.0, compute capability: 8.9
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1721655938.235588 1639261 service.cc:145] XLA service 0x7bee28009db0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1721655938.235611 1639261 service.cc:153]   StreamExecutor device (0): NVIDIA GeForce RTX 4090, Compute Capability 8.9
# 2024-07-22 15:45:38.250400: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:268] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2024-07-22 15:45:38.318097: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:465] Loaded cuDNN version 8902
#  1/13 ━━━━━━━━━━━━━━━━━━━━ 14s 1s/step - loss: 5.4628
# I0000 00:00:1721655939.011225 1639261 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 5.3909
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 5.3764
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 905us/step - loss: 5.1271
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 589us/step - loss: 5.1524
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 430us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 532us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 369us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 449us/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 632us/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 481us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 500us/step - loss: 4.9130
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 545us/step - loss: 4.9416
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 588us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 955us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 414us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 450us/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 569us/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 451us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 485us/step - loss: 4.7133
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 458us/step - loss: 4.7421
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 442us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 452us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 491us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 485us/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 419us/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 565us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 491us/step - loss: 4.5222
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 519us/step - loss: 4.5524
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 446us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 539us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 398us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 404us/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 469us/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 440us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 493us/step - loss: 4.3397
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 610us/step - loss: 4.3697
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 563us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 570us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 431us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 588us/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 738us/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 632us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 529us/step - loss: 4.1656
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 557us/step - loss: 4.1957
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 517us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 464us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 408us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 449us/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 486us/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 513us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 547us/step - loss: 3.9985
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 539us/step - loss: 4.0293
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 453us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 428us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 428us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 406us/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 606us/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 442us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 555us/step - loss: 3.8382
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 477us/step - loss: 3.8692
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 495us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 429us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 487us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 546us/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 634us/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 447us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 682us/step - loss: 3.6849
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 531us/step - loss: 3.7157
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 540us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 649us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 453us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 413us/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 484us/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 467us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 494us/step - loss: 3.5383
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 521us/step - loss: 3.5674
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 415us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 486us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 458us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 430us/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 441us/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 517us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 478us/step - loss: 3.3961
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 490us/step - loss: 3.4255
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 414us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 572us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 494us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 420us/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 463us/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 495us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 919us/step - loss: 3.2610
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 488us/step - loss: 3.2899
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 461us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 418us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 468us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 433us/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 531us/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 432us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 525us/step - loss: 3.1316
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 483us/step - loss: 3.1605
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 507us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 558us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 487us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 659us/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 708us/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 454us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 575us/step - loss: 3.0065
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 822us/step - loss: 3.0348
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 387us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 939us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 657us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 404us/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 466us/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 505us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 545us/step - loss: 2.8876
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 464us/step - loss: 2.9152
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 441us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 628us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 505us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 597us/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 524us/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 499us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 489us/step - loss: 2.7728
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 466us/step - loss: 2.8006
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 441us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 419us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 425us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 588us/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 683us/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 590us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 458us/step - loss: 2.6636
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 471us/step - loss: 2.6892
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 575us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 352us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 363us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 472us/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 388us/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 412us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 502us/step - loss: 2.5587
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 516us/step - loss: 2.5833
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 404us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 408us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 375us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 416us/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 501us/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 600us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 467us/step - loss: 2.4583
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 465us/step - loss: 2.4806
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 373us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 549us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 464us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 381us/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 431us/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 450us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 445us/step - loss: 2.3603
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 483us/step - loss: 2.3838
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 410us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 393us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 458us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 654us/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 549us/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 610us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 541us/step - loss: 2.2681
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 521us/step - loss: 2.2910
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 440us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 394us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 431us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 645us/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 597us/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 598us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 527us/step - loss: 2.1797
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 469us/step - loss: 2.1998
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 442us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 425us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 392us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 370us/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 426us/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 461us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 439us/step - loss: 2.0931
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 475us/step - loss: 2.1141
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 519us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 441us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 505us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 603us/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 449us/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 449us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 515us/step - loss: 2.0105
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 482us/step - loss: 2.0309
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 427us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 409us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 411us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 380us/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 561us/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 416us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 493us/step - loss: 1.9318
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 434us/step - loss: 1.9518
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 400us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 501us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 399us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 392us/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 588us/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 716us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 480us/step - loss: 1.8569
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 780us/step - loss: 1.8752
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 359us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 451us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 518us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 414us/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 598us/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 903us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 533us/step - loss: 1.7838
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 611us/step - loss: 1.8021
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 690us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 461us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 617us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 413us/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 620us/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 509us/step - loss: 1.7142
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 607us/step - loss: 1.7311
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 408us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 395us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 435us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 462us/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 467us/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 488us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 467us/step - loss: 1.6480
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 502us/step - loss: 1.6641
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 419us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 447us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 442us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 454us/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 660us/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 482us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 519us/step - loss: 1.5831
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 540us/step - loss: 1.5987
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 506us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 446us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 431us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 596us/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 621us/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 496us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 479us/step - loss: 1.5218
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 464us/step - loss: 1.5357
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 383us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 478us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 428us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 467us/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 491us/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 480us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 583us/step - loss: 1.4631
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 536us/step - loss: 1.4761
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 559us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 443us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 405us/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 620us/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 480us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 528us/step - loss: 1.4060
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 563us/step - loss: 1.4190
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 492us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 390us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 376us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 397us/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 473us/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 751us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 522us/step - loss: 1.3516
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 531us/step - loss: 1.3639
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 387us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 421us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 478us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 360us/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 435us/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 488us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 532us/step - loss: 1.2994
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 521us/step - loss: 1.3108
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 607us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 512us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 452us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 403us/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 473us/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 542us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 483us/step - loss: 1.2497
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 612us/step - loss: 1.2593
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 682us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 412us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 505us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 412us/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 449us/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 556us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 730us/step - loss: 1.2018
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 513us/step - loss: 1.2102
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 400us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 415us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 397us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 434us/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 448us/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 488us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 542us/step - loss: 1.1548
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 455us/step - loss: 1.1640
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 406us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 365us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 383us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 451us/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 623us/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 699us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 528us/step - loss: 1.1111
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 474us/step - loss: 1.1188
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 469us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 400us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 470us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 508us/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 451us/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 421us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 454us/step - loss: 1.0687
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 435us/step - loss: 1.0753
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 382us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 367us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 425us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 503us/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 454us/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 995us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 586us/step - loss: 1.0278
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 488us/step - loss: 1.0335
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 583us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 426us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 438us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 398us/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 543us/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 438us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 511us/step - loss: 0.9882
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 540us/step - loss: 0.9938
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 383us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 375us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 396us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 537us/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 559us/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 419us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 438us/step - loss: 0.9497
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 490us/step - loss: 0.9562
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 441us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 528us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 537us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 364us/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 444us/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 417us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 522us/step - loss: 0.9140
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 453us/step - loss: 0.9184
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 547us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 540us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 470us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 393us/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 412us/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 426us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 544us/step - loss: 0.8786
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 538us/step - loss: 0.8825
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 425us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 373us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 523us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 378us/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 440us/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 486us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 494us/step - loss: 0.8451
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 503us/step - loss: 0.8494
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 578us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 398us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 418us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 468us/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 419us/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 425us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 458us/step - loss: 0.8129
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 486us/step - loss: 0.8165
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 395us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 393us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 419us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 380us/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 578us/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 427us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 468us/step - loss: 0.7828
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 419us/step - loss: 0.7853
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 412us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 490us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 366us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 757us/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 478us/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 482us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 507us/step - loss: 0.7532
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 464us/step - loss: 0.7554
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 390us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 454us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 432us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 386us/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 650us/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 706us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 540us/step - loss: 0.7244
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 510us/step - loss: 0.7258
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 488us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 415us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 466us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 658us/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 553us/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 519us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 450us/step - loss: 0.6965
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 460us/step - loss: 0.6987
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 401us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 748us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 419us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 454us/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 498us/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 466us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 480us/step - loss: 0.6707
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 539us/step - loss: 0.6725
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 436us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 527us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 457us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 601us/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 460us/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 466us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 507us/step - loss: 0.6457
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 511us/step - loss: 0.6459
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 475us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 455us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 569us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 552us/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 463us/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 505us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 630us/step - loss: 0.6207
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 482us/step - loss: 0.6218
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 487us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 499us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 348us/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 830us/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 451us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 448us/step - loss: 0.5972
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 465us/step - loss: 0.5983
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 380us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 400us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 452us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 387us/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 681us/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 521us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 477us/step - loss: 0.5745
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 482us/step - loss: 0.5751
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 375us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 381us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 587us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 614us/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 469us/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 418us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 484us/step - loss: 0.5535
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 445us/step - loss: 0.5535
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 587us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 569us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 455us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 363us/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 601us/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 674us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 452us/step - loss: 0.5329
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 515us/step - loss: 0.5328
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 621us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 604us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 412us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 546us/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 551us/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 593us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 528us/step - loss: 0.5127
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 623us/step - loss: 0.5137
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 370us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 436us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 446us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 433us/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 667us/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 532us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 637us/step - loss: 0.4934
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 559us/step - loss: 0.4930
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 426us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 434us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 466us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 362us/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 605us/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 663us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 448us/step - loss: 0.4758
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 493us/step - loss: 0.4751
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 383us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 505us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 411us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 400us/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 497us/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 508us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 570us/step - loss: 0.4585
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 770us/step - loss: 0.4573
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 533us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 742us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 442us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 428us/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 608us/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 677us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 575us/step - loss: 0.4416
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 554us/step - loss: 0.4396
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 414us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 629us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 372us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 637us/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 473us/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 659us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 561us/step - loss: 0.4250
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 495us/step - loss: 0.4232
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 351us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 384us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 421us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 448us/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 427us/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 724us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 599us/step - loss: 0.4090
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 511us/step - loss: 0.4081
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 542us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 479us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 373us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 427us/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 856us/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 542us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 488us/step - loss: 0.3943
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 515us/step - loss: 0.3932
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 497us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 550us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 356us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 378us/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 571us/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 479us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 623us/step - loss: 0.3798
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 603us/step - loss: 0.3781
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 428us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 428us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 414us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 475us/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 526us/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 714us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 620us/step - loss: 0.3656
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 557us/step - loss: 0.3638
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 425us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 509us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 555us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 446us/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 666us/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 652us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 529us/step - loss: 0.3521
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 551us/step - loss: 0.3519
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 476us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 448us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 539us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 396us/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 449us/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 436us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 468us/step - loss: 0.3393
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 470us/step - loss: 0.3374
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 411us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 478us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 536us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 441us/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 575us/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 644us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 454us/step - loss: 0.3276
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 493us/step - loss: 0.3264
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 594us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 415us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 590us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 476us/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 511us/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 688us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 457us/step - loss: 0.3158
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 445us/step - loss: 0.3139
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 398us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 379us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 634us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 440us/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 872us/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 661us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 463us/step - loss: 0.3048
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 477us/step - loss: 0.3026
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 427us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 576us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 442us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 411us/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 420us/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 568us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 514us/step - loss: 0.2927
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 527us/step - loss: 0.2917
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 373us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 381us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 413us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 544us/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 479us/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 419us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 403us/step - loss: 0.2828
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 438us/step - loss: 0.2808
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 501us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 412us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 387us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 396us/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 426us/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 530us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 506us/step - loss: 0.2723
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 489us/step - loss: 0.2706
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 535us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 770us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 424us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 498us/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 428us/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 423us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 485us/step - loss: 0.2627
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 419us/step - loss: 0.2610
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 432us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 412us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 417us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 409us/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 443us/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 476us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 495us/step - loss: 0.2538
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 536us/step - loss: 0.2511
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 433us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 450us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 403us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 378us/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 572us/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 429us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 538us/step - loss: 0.2452
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 471us/step - loss: 0.2433
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 527us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 427us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 425us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 383us/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 489us/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 725us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 531us/step - loss: 0.2363
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 510us/step - loss: 0.2347
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 485us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 406us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 385us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 378us/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 581us/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 636us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 512us/step - loss: 0.2275
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 541us/step - loss: 0.2259
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 398us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 445us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 371us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 410us/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 531us/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 480us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 541us/step - loss: 0.2204
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 501us/step - loss: 0.2176
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 410us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 473us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 410us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 474us/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 462us/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 457us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 522us/step - loss: 0.2126
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 466us/step - loss: 0.2115
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 484us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 419us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 366us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 541us/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 590us/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 504us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 509us/step - loss: 0.2057
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 635us/step - loss: 0.2031
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 442us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 467us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 405us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 487us/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 528us/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 725us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 581us/step - loss: 0.1982
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 528us/step - loss: 0.1963
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 499us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 576us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 585us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 491us/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 495us/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 442us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 624us/step - loss: 0.1917
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 581us/step - loss: 0.1901
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 459us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 388us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 434us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 425us/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 465us/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 548us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 569us/step - loss: 0.1850
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 525us/step - loss: 0.1836
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 395us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 427us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 403us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 527us/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 489us/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 688us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 576us/step - loss: 0.1793
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 525us/step - loss: 0.1773
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 649us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 441us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 507us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 421us/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 675us/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 500us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 659us/step - loss: 0.1729
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 469us/step - loss: 0.1715
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 411us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 419us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 476us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 504us/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 626us/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 708us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 557us/step - loss: 0.1679
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 528us/step - loss: 0.1652
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 418us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 513us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 520us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 447us/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 652us/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 525us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 760us/step - loss: 0.1620
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 545us/step - loss: 0.1597
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 549us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 364us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 367us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 677us/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 606us/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 502us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 566us/step - loss: 0.1564
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 553us/step - loss: 0.1554
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 427us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 405us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 487us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 468us/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 474us/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 454us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 723us/step - loss: 0.1519
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 534us/step - loss: 0.1505
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 456us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 420us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 452us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 487us/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 477us/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 430us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 492us/step - loss: 0.1466
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 497us/step - loss: 0.1457
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 430us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 584us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 681us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 656us/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 431us/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 385us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 470us/step - loss: 0.1421
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 435us/step - loss: 0.1404
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 424us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 385us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 397us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 358us/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 467us/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 447us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 441us/step - loss: 0.1382
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 492us/step - loss: 0.1357
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 386us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 400us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 405us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 428us/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 437us/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 439us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 619us/step - loss: 0.1341
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 522us/step - loss: 0.1317
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 600us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 591us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 470us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 409us/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 470us/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 454us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 488us/step - loss: 0.1295
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 474us/step - loss: 0.1274
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 477us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 379us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 381us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 382us/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 549us/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 729us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 444us/step - loss: 0.1254
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 461us/step - loss: 0.1240
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 474us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 446us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 398us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 643us/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 528us/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 536us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 409us/step - loss: 0.1214
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 495us/step - loss: 0.1197
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 387us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 422us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 387us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 485us/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 585us/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 698us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 650us/step - loss: 0.1181
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 575us/step - loss: 0.1159
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 665us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 603us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 409us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 409us/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 653us/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 741us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 652us/step - loss: 0.1149
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 669us/step - loss: 0.1135
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 517us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 426us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 421us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 451us/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 507us/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 640us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 449us/step - loss: 0.1111
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 409us/step - loss: 0.1086
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 417us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 417us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 401us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 469us/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 532us/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 435us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 586us/step - loss: 0.1078
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 590us/step - loss: 0.1063
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 396us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 424us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 564us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 494us/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 668us/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 541us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 565us/step - loss: 0.1044
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 491us/step - loss: 0.1028
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 391us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 464us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 367us/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 496us/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 700us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 554us/step - loss: 0.1019
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 590us/step - loss: 0.1008
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 590us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 588us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 423us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 547us/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 710us/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 589us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 574us/step - loss: 0.0990
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 520us/step - loss: 0.0979
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 556us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 636us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 465us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 399us/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 437us/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 452us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 516us/step - loss: 0.0961
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 505us/step - loss: 0.0942
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 371us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 377us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 414us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 421us/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 898us/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 476us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 485us/step - loss: 0.0933
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 514us/step - loss: 0.0927
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 421us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 492us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 531us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 426us/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 663us/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 493us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 547us/step - loss: 0.0907
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 556us/step - loss: 0.0894
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 472us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 476us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 394us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 370us/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 519us/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 587us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 588us/step - loss: 0.0879
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 710us/step - loss: 0.0874
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 513us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 384us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 379us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 445us/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 536us/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 467us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 452us/step - loss: 0.0862
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 542us/step - loss: 0.0846
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 435us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 374us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 555us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 605us/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 529us/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 473us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 420us/step - loss: 0.0838
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 460us/step - loss: 0.0828
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 365us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 368us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 465us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 483us/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 729us/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 456us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 638us/step - loss: 0.0813
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 530us/step - loss: 0.0808
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 396us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 433us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 358us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 409us/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 608us/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 501us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 523us/step - loss: 0.0803
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 519us/step - loss: 0.0788
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 416us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 541us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 400us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 389us/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 456us/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 420us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 513us/step - loss: 0.0771
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 471us/step - loss: 0.0765
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 421us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 544us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 422us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 393us/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 404us/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 435us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 460us/step - loss: 0.0764
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 454us/step - loss: 0.0752
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 687us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 410us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 754us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 383us/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 472us/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 429us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 440us/step - loss: 0.0747
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 861us/step - loss: 0.0733
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 448us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 474us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 389us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 366us/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 582us/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 600us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 449us/step - loss: 0.0726
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 548us/step - loss: 0.0712
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 392us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 551us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 700us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 421us/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 503us/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 526us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 546us/step - loss: 0.0705
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 551us/step - loss: 0.0693
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 455us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 577us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 543us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 406us/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 505us/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 408us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 455us/step - loss: 0.0686
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 417us/step - loss: 0.0682
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 429us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 507us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 381us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 447us/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 484us/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 782us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 547us/step - loss: 0.0675
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 435us/step - loss: 0.0667
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 560us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 360us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 390us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 454us/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 715us/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 462us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 458us/step - loss: 0.0667
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 623us/step - loss: 0.0652
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 435us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 611us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 417us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 831us/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 470us/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 584us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 555us/step - loss: 0.0650
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 442us/step - loss: 0.0642
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 426us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 381us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 533us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 429us/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 417us/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 395us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 501us/step - loss: 0.0638
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 485us/step - loss: 0.0619
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 363us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 435us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 478us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 611us/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 590us/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 457us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 523us/step - loss: 0.0624
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 512us/step - loss: 0.0619
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 657us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 410us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 486us/step
# ...
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 528us/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 512us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 534us/step - loss: 0.1003
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 500us/step - loss: 0.1252
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 401us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 537us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 444us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 401us/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 453us/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 556us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 564us/step - loss: 0.0965
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 462us/step - loss: 0.1203
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 428us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 415us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 580us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 383us/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 499us/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 413us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 499us/step - loss: 0.0942
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 662us/step - loss: 0.1176
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 464us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 537us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 495us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 428us/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 459us/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 484us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 566us/step - loss: 0.0910
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 528us/step - loss: 0.1139
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 466us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 429us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 553us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 431us/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 461us/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 444us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 546us/step - loss: 0.0887
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 561us/step - loss: 0.1119
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 706us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 685us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 672us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 522us/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 472us/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 538us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 528us/step - loss: 0.0856
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 533us/step - loss: 0.1077
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 420us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 436us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 383us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 404us/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 513us/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 419us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 484us/step - loss: 0.0835
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 469us/step - loss: 0.1044
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 621us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 555us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 419us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 410us/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 569us/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 543us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 526us/step - loss: 0.0819
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 445us/step - loss: 0.1015
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 601us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 490us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 440us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 407us/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 461us/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 465us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 531us/step - loss: 0.0800
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 556us/step - loss: 0.0993
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 456us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 743us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 505us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 400us/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 456us/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 580us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 456us/step - loss: 0.0769
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 465us/step - loss: 0.0964
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 417us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 528us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 488us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 573us/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 433us/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 736us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 502us/step - loss: 0.0743
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 570us/step - loss: 0.0936
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 413us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 440us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 508us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 406us/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 462us/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 597us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 493us/step - loss: 0.0726
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 583us/step - loss: 0.0911
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 481us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 407us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 429us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 415us/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 699us/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 726us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 506us/step - loss: 0.0714
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 629us/step - loss: 0.0893
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 850us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 412us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 656us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 528us/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 527us/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 748us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 470us/step - loss: 0.0694
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 492us/step - loss: 0.0871
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 562us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 403us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 461us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 469us/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 631us/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 642us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 522us/step - loss: 0.0683
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 617us/step - loss: 0.0851
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 529us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 466us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 434us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 563us/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 526us/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 551us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 510us/step - loss: 0.0667
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 514us/step - loss: 0.0825
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 404us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 403us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 439us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 493us/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 519us/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 644us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 734us/step - loss: 0.0637
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 487us/step - loss: 0.0807
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 400us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 473us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 436us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 599us/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 691us/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 708us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 559us/step - loss: 0.0633
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 594us/step - loss: 0.0782
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 543us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 638us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 599us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 413us/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 449us/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 859us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 588us/step - loss: 0.0626
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 511us/step - loss: 0.0774
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 582us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 460us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 474us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 479us/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 500us/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 488us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 463us/step - loss: 0.0604
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 526us/step - loss: 0.0757
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 564us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 388us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 583us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 412us/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 660us/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 783us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 545us/step - loss: 0.0591
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 551us/step - loss: 0.0733
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 535us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 454us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 469us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 523us/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 568us/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 692us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 548us/step - loss: 0.0579
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 580us/step - loss: 0.0715
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 555us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 494us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 621us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 429us/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 768us/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 669us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 527us/step - loss: 0.0561
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 488us/step - loss: 0.0706
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 581us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 590us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 438us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 498us/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 469us/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 455us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 519us/step - loss: 0.0553
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 543us/step - loss: 0.0689
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 509us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 529us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 506us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 484us/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 501us/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 493us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 651us/step - loss: 0.0539
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 501us/step - loss: 0.0669
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 466us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 474us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 469us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 460us/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 588us/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 886us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 472us/step - loss: 0.0533
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 526us/step - loss: 0.0656
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 498us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 412us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 476us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 382us/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 621us/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 437us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 569us/step - loss: 0.0513
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 482us/step - loss: 0.0647
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 430us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 431us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 403us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 469us/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 474us/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 532us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 531us/step - loss: 0.0517
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 497us/step - loss: 0.0624
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 466us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 496us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 531us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 521us/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 471us/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 599us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 525us/step - loss: 0.0497
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 559us/step - loss: 0.0622
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 481us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 500us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 413us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 650us/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 522us/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 637us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 481us/step - loss: 0.0488
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 484us/step - loss: 0.0605
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 677us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 613us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 451us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 464us/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 544us/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 469us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 527us/step - loss: 0.0483
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 595us/step - loss: 0.0596
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 455us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 391us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 418us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 385us/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 419us/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 449us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 516us/step - loss: 0.0479
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 604us/step - loss: 0.0588
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 635us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 415us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 445us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 422us/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 532us/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 476us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 501us/step - loss: 0.0471
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 502us/step - loss: 0.0568
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 439us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 484us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 443us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 457us/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 529us/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 504us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 748us/step - loss: 0.0455
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 508us/step - loss: 0.0560
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 517us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 597us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 403us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 459us/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 582us/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 506us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 500us/step - loss: 0.0448
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 456us/step - loss: 0.0549
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 367us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 398us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 414us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 454us/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 643us/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 534us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 489us/step - loss: 0.0445
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 509us/step - loss: 0.0555
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 532us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 437us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 491us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 444us/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 431us/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 575us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 525us/step - loss: 0.0435
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 503us/step - loss: 0.0529
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 574us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 480us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 435us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 453us/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 558us/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 638us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 494us/step - loss: 0.0431
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 476us/step - loss: 0.0534
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 383us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 438us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 567us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 482us/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 445us/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 695us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 522us/step - loss: 0.0429
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 454us/step - loss: 0.0510
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 393us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 575us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 430us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 683us/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 520us/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 645us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 577us/step - loss: 0.0419
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 556us/step - loss: 0.0518
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 420us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 432us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 423us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 441us/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 450us/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 511us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 547us/step - loss: 0.0414
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 505us/step - loss: 0.0498
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 457us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 416us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 640us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 494us/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 471us/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 547us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 512us/step - loss: 0.0408
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 512us/step - loss: 0.0491
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 412us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 426us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 672us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 470us/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 638us/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 452us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 562us/step - loss: 0.0407
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 530us/step - loss: 0.0490
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 429us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 617us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 506us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 427us/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 467us/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 563us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 545us/step - loss: 0.0395
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 524us/step - loss: 0.0476
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 460us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 468us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 424us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 434us/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 636us/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 458us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 624us/step - loss: 0.0398
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 553us/step - loss: 0.0475
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 533us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 480us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 452us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 454us/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 537us/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 535us/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 534us/step - loss: 0.0389
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 541us/step - loss: 0.0470
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 504us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 485us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 459us/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 506us/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 542us/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 600us/step

# %%
epsilon = np.array(epsilon, dtype='float64')
bias = np.array(bias, dtype='float64')
std = np.array(std, dtype = 'float64')

training_loss_dec0 = np.array(training_loss_dec0, dtype = 'float64')
training_loss_dec1 = np.array(training_loss_dec1, dtype = 'float64')


print(np.where(epsilon == np.min(epsilon)), np.min(epsilon))
index = 3
plt.figure(figsize=(14,8))

plt.subplot(2,2,1)
for i in range(epsilon.shape[0]):
  plt.plot(np.log10(std[i,:]))
plt.ylabel('Logarithm of std')
plt.xlabel('Epochs')
plt.title('All seeds')

plt.subplot(2,2,2)
for i in range(training_loss_dec0.shape[0]):
  label = 'Seed' + ' ' + str(i)
  plt.plot(np.log10(bias[i,:]), label = label)
plt.legend()
plt.ylabel('Logarithm of bias')
plt.xlabel('Epochs')
plt.title('All seeds')


plt.subplot(2,2,3)
plt.plot(np.log10(epsilon[index,:]), label = 'Epsilon')
plt.plot(np.log10(bias[index,:]), label = 'Bias')
plt.plot(np.log10(std[index,:]), label = 'std')
plt.legend()
plt.ylabel('Logarithm of epsilon')
plt.xlabel('Epochs')

plt.subplot(2,2,4)
plt.plot(np.log10(training_loss_dec0[index,:]), label = 'Detector 0')
plt.plot(np.log10(training_loss_dec1[index,:]), label = 'Detector 1')
plt.ylabel('Logarithm of training loss')
plt.xlabel('Epochs')

plt.legend()
# Out:
# (array([0]), array([23])) 0.0632493820744377

# %%
epoch = 23
#------------------------------------------- Histogram and gaussian fit -----------------------------------------------
nbins = 51
histogN_V82, binsN, patchesN  = plt.hist(TOFN_V82_array[index,epoch,:] - np.mean(TOFN_V55_array[index,epoch,:]), bins = nbins,range = [-0.8,0.8],alpha = 0.5, label = 'V82');
cbinsN = 0.5*(binsN[1:]+binsN[0:-1])
HN, AN, x0N_V82, sigmaN_V82 = gauss_fit(cbinsN, histogN_V82)

histogN_V55, binsN, patchesN  = plt.hist(TOFN_V55_array[index,epoch,:] - np.mean(TOFN_V55_array[index,epoch,:]), bins = nbins,range = [-0.8,0.8],alpha = 0.5, label = 'V55');
cbinsN = 0.5*(binsN[1:]+binsN[0:-1])
HN, AN, x0N_V55, sigmaN_V55 = gauss_fit(cbinsN, histogN_V55)

histogN_V28, binsN, patchesN  = plt.hist(TOFN_V28_array[index,epoch,:] - np.mean(TOFN_V55_array[index,epoch,:]), bins = nbins,range = [-0.8,0.8],alpha = 0.5, label = 'V28');
cbinsN = 0.5*(binsN[1:]+binsN[0:-1])
HN, AN, x0N_V28, sigmaN_V28 = gauss_fit(cbinsN, histogN_V28)
plt.legend()


FWHMN_V82 = 2.35482 * sigmaN_V82
FWHMN_V55 = 2.35482 * sigmaN_V55
FWHMN_V28 = 2.35482 * sigmaN_V28


print('')
print("V82: CENTROID(ns) = %.3f  FWHM(ns) = %.3f  std(ns) = %.3f" % (x0N_V82, FWHMN_V82, sigmaN_V82))
print("V55: CENTROID(ns) = %.3f  FWHM(ns) = %.3f  std(ns) = %.3f" % (x0N_V55, FWHMN_V55, sigmaN_V55))
print("V28: CENTROID(ns) = %.3f  FWHM(ns) = %.3f  std(ns) = %.3f" % (x0N_V28, FWHMN_V28, sigmaN_V28))
# Out:
# V82: CENTROID(ns) = 0.162  FWHM(ns) = 0.157  std(ns) = 0.067
# V55: CENTROID(ns) = -0.001  FWHM(ns) = 0.134  std(ns) = 0.057
# V28: CENTROID(ns) = -0.215  FWHM(ns) = 0.156  std(ns) = 0.066

# %%
Error_V82 = (TOFN_V82_array[index,epoch,:] - np.mean(TOFN_V55_array[index,epoch,:]) - 0.2)**2 
Error_V55 = (TOFN_V55_array[index,epoch,:] - np.mean(TOFN_V55_array[index,epoch,:]))**2 
Error_V28 = (TOFN_V28_array[index,epoch,:] - np.mean(TOFN_V55_array[index,epoch,:]) + 0.2)**2 

Error = np.concatenate((Error_V82, Error_V55, Error_V28)) 
MSE = np.mean(Error)   
print(MSE)
# Out:
# 0.005059854616777218

# %% [markdown]
# # **ENSEMBLE MODEL**

# %%
#---------------------------- Get the weighted mean by the accuracy of their bias result ------------------------------------------
weighted_mean_V28 = np.average(np.squeeze(TOFN_V28_array[:,epoch,:]), weights = (1/bias[:,epoch]), axis = 0)
weighted_mean_V55 = np.average(np.squeeze(TOFN_V55_array[:,epoch,:]), weights = (1/bias[:,epoch]), axis = 0)
weighted_mean_V82 = np.average(np.squeeze(TOFN_V82_array[:,epoch,:]), weights = (1/bias[:,epoch]), axis = 0)

# %%
#------------------------------------------- Histogram and gaussian fit -----------------------------------------------
histogN_V82, binsN, patchesN  = plt.hist(weighted_mean_V82 - np.mean(weighted_mean_V55), bins = nbins, range = [-0.8,0.8], alpha = 0.5, label = 'V82');
cbinsN = 0.5*(binsN[1:]+binsN[0:-1])
HN, AN, x0N_V82, sigmaN_V82 = gauss_fit(cbinsN, histogN_V82)

histogN_V55, binsN, patchesN  = plt.hist(weighted_mean_V55 - np.mean(weighted_mean_V55), bins = nbins, range = [-0.8,0.8], alpha = 0.5, label = 'V55');
cbinsN = 0.5*(binsN[1:]+binsN[0:-1])
HN, AN, x0N_V55, sigmaN_V55 = gauss_fit(cbinsN, histogN_V55)

histogN_V28, binsN, patchesN  = plt.hist(weighted_mean_V28 - np.mean(weighted_mean_V55), bins = nbins, range = [-0.8,0.8], alpha = 0.5, label = 'V28');
cbinsN = 0.5*(binsN[1:]+binsN[0:-1])
HN, AN, x0N_V28, sigmaN_V28 = gauss_fit(cbinsN, histogN_V28)
plt.legend()


FWHMN_V82 = 2.35482 * sigmaN_V82
FWHMN_V55 = 2.35482 * sigmaN_V55
FWHMN_V28 = 2.35482 * sigmaN_V28


print('')
print("V82: CENTROID(ns) = %.3f  FWHM(ns) = %.3f  std(ns) = %.3f" % (x0N_V82, FWHMN_V82, sigmaN_V82))
print("V55: CENTROID(ns) = %.3f  FWHM(ns) = %.3f  std(ns) = %.3f" % (x0N_V55, FWHMN_V55, sigmaN_V55))
print("V28: CENTROID(ns) = %.3f  FWHM(ns) = %.3f  std(ns) = %.3f" % (x0N_V28, FWHMN_V28, sigmaN_V28))
# Out:
# V82: CENTROID(ns) = 0.173  FWHM(ns) = 0.153  std(ns) = 0.065
# V55: CENTROID(ns) = 0.010  FWHM(ns) = 0.139  std(ns) = 0.059
# V28: CENTROID(ns) = -0.206  FWHM(ns) = 0.169  std(ns) = 0.072
